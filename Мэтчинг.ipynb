# %% [markdown]
# Артём Панов, TG - @arsepan

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Необходимо разработать алгоритм, который для всех товаров из validation.csv предложит несколько вариантов наиболее похожих товаров из base, оценить качество алгоритма по метрике accuracy@5. Речь идёт о задаче метчинга - для каждого объекта из множества A найти один или несколько объектов из B, которые близки к нему по некоторой заданной метрике.
#
# Данные:
# - **base.csv** - анонимизированный набор товаров. Каждый товар представлен как уникальный id (0-base, 1-base, 2-base) и вектор признаков размерностью 72.
# - **train.csv -** обучающий датасет. Каждая строчка - один товар, для которого известен уникальный id (0-query, 1-query, …) , вектор признаков И id товара из *base.csv*, который максимально похож на него (по мнению экспертов).
# - **validation.csv** - датасет с товарами (уникальный id и вектор признаков), для которых надо найти наиболее близкие товары из *base.csv*
# - **validation_answer.csv** - правильные ответы к предыдущему файлу.

# %% [markdown]
# ## Создание зависимостей и функций

# %%
import pandas as pd
import numpy as np
import faiss

from sklearn.preprocessing import StandardScaler

# %%
def show_df(df):
    display(df.head(3))
    print(f'Количество наблюдений: {df.shape[0]}')
    print(f'Количество признаков: {df.shape[1]}')
    print(f'Количество NaN значений: {df.isna().sum().sum()}')
    print(f'Количество дубликатов: {df.duplicated().sum()}')
    try:
        print(f'Значение размаха: {min(list(df.min()[:-1])), max(list(df.max()[:-1]))}')
    except:
        pass

# %% [markdown]
# ## Распаковка данных

# %% [markdown]
# **Base** - можно сказать, что это база данных готовых векторов после определённого преобразования. Именно из этой БД мы будем искать самые близкие товары.

# %%
base = pd.read_csv('base.csv', index_col='Id')
show_df(base)
# Out:
#                  0          1          2          3           4           5  \
# Id
# 0-base -115.083890  11.152912 -64.426760 -118.88089  216.482440 -104.698060
# 1-base  -34.562202  13.332763 -69.787610 -166.53348   57.680607  -86.098370
# 2-base  -54.233746   6.379371 -29.210136 -133.41383  150.895830  -99.435326
#
#                  6          7           8          9  ...          62  \
# Id                                                    ...
# 0-base -469.070588  44.348083  120.915344  181.44970  ...  -42.808693
# 1-base  -85.076666 -35.637436  119.718636  195.23419  ... -117.767525
# 2-base   52.554795  62.381706  128.951450  164.38147  ...  -76.397800
#
#                63         64          65        66         67         68  \
# Id
# 0-base  38.800827 -151.76218  -74.389090  63.66634  -4.703861   92.93361
# 1-base  41.100000 -157.82940  -94.446806  68.20211  24.346846  179.93793
# 2-base  46.011803 -207.14442  127.325570  65.56618  66.325680   81.07349
#
#                 69           70         71
# Id
# 0-base  115.269190  -112.756640 -60.830353
# 1-base  116.834000   -84.888941 -59.524610
# 2-base  116.594154 -1074.464888 -32.527206
#
# [3 rows x 72 columns]
# Количество наблюдений: 2918139
# Количество признаков: 72
# Количество NaN значений: 0
# Количество дубликатов: 0
# Значение размаха: (-1297.931468499947, 1557.433379634992)

# %%
train = pd.read_csv('train.csv', index_col='Id')
show_df(train)
# Out:
#                  0          1           2          3          4         5  \
# Id
# 0-query -53.882748  17.971436  -42.117104 -183.93668  187.51749 -87.14493
# 1-query -87.776370   6.806268  -32.054546 -177.26039  120.80333 -83.81059
# 2-query -49.979565   3.841486 -116.118590 -180.40198  190.12843 -50.83762
#
#                   6          7           8           9  ...         63  \
# Id                                                      ...
# 0-query -347.360606  38.307602  109.085560   30.413513  ...  70.107360
# 1-query  -94.572749 -78.433090  124.915900  140.331070  ...   4.669178
# 2-query   26.943937 -30.447489  125.771164  211.607820  ...  78.039764
#
#                 64          65         66         67          68         69  \
# Id
# 0-query -155.80257 -101.965943  65.903790  34.457500   62.642094  134.76360
# 1-query -151.69771   -1.638704  68.170876  25.096191   89.974976  130.58963
# 2-query -169.14620   82.144186  66.008220  18.400496  212.409730  121.93147
#
#                   70         71        Target
# Id
# 0-query  -415.750254 -25.958572   675816-base
# 1-query -1035.092211 -51.276833   366656-base
# 2-query -1074.464888 -22.547178  1447819-base
#
# [3 rows x 73 columns]
# Количество наблюдений: 100000
# Количество признаков: 73
# Количество NaN значений: 0
# Количество дубликатов: 0
# Значение размаха: (-1297.8719841036757, 1557.383334499213)

# %%
validation = pd.read_csv('validation.csv', index_col='Id')
show_df(validation)
# Out:
#                       0          1          2          3          4  \
# Id
# 100000-query -57.372734   3.597752 -13.213642 -125.92679  110.74594
# 100001-query -53.758705  12.790300 -43.268543 -134.41762  114.44991
# 100002-query -64.175095  -3.980927  -7.679249 -170.16093   96.44616
#
#                       5           6           7           8           9  ...  \
# Id                                                                       ...
# 100000-query -81.279594 -461.003172  139.815720  112.880980   75.215750  ...
# 100001-query -90.520130 -759.626065   63.995087  127.117905   53.128998  ...
# 100002-query -62.377740 -759.626065   87.477554  131.270110  168.920320  ...
#
#                      62         63         64          65        66  \
# Id
# 100000-query  -75.51302  52.830902 -143.43945   59.051935  69.28224
# 100001-query  -79.44183  29.185436 -168.60590  -82.872443  70.76560
# 100002-query -134.79541  37.368730 -159.66231 -119.232725  67.71044
#
#                      67         68          69           70          71
# Id
# 100000-query  61.927513  111.59253  115.140656 -1099.130485 -117.079360
# 100001-query -65.975950   97.07716  123.391640  -744.442332  -25.009320
# 100002-query  86.002060  137.63641  141.081630  -294.052271  -70.969604
#
# [3 rows x 72 columns]
# Количество наблюдений: 100000
# Количество признаков: 72
# Количество NaN значений: 0
# Количество дубликатов: 0
# Значение размаха: (-1297.9239987642586, 1557.293478372255)

# %%
validation_answer = pd.read_csv('validation_answer.csv', index_col='Id')
show_df(validation_answer)
# Out:
#                   Expected
# Id
# 100000-query  2676668-base
# 100001-query    91606-base
# 100002-query   472256-base
# Количество наблюдений: 100000
# Количество признаков: 1
# Количество NaN значений: 0
# Количество дубликатов: 8498

# %% [markdown]
# ## Подготовка данных

# %%
features = train.drop('Target', axis=1)
target = train['Target']
print(f'Features shape: {features.shape}')
print(f'Target shape: {target.shape}')
# Out:
# Features shape: (100000, 72)
# Target shape: (100000,)

# %%
scaler = StandardScaler()

features_idx = features.index.tolist()
features_sc = scaler.fit_transform(features)
features = pd.DataFrame(index=features_idx, data=features_sc)

base_idx = base.index.tolist()
base_sc = scaler.transform(base)
base = pd.DataFrame(index=base_idx, data=base_sc)

# %%
features.head()
# Out:
#                0         1         2         3         4         5         6   \
# 0-query  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 1-query -0.094858 -0.173152  0.296912 -1.523962  0.189363 -0.370205  1.240223
# 2-query  1.369923 -0.771418 -1.852466 -1.677699  1.642697  0.777931  1.675742
# 3-query  1.453981  0.286998 -1.834136  1.228656 -0.358857 -1.256206 -1.198981
# 4-query  0.220765  1.367848 -0.389568 -0.045702 -1.145549  1.982654  0.427564
#
#                7         8         9   ...        62        63        64  \
# 0-query  0.258787 -2.153763 -1.474397  ... -0.791579  1.309634 -0.087262
# 1-query -1.510417  0.284657  0.218924  ...  1.314829 -1.270984  0.012808
# 2-query -0.783196  0.416398  1.316968  ...  0.949086  1.622456 -0.412557
# 3-query  0.878306  0.144055  1.795195  ...  0.638241  0.300385  0.165927
# 4-query  0.375133  0.442602 -0.350126  ...  0.403412  0.320641 -1.069452
#
#                65        66        67        68        69        70        71
# 0-query -1.170455 -1.031430  0.206023 -0.173143  0.906949  0.724239  0.547062
# 1-query -0.157858  0.202021  0.037262  0.266272  0.713549 -0.801388 -0.067236
# 2-query  0.687758 -0.974613 -0.083446  2.234588  0.312377 -0.898375  0.629833
# 3-query  0.807328 -1.995759  1.496880  0.157014  0.143082 -0.898375  0.693994
# 4-query -1.328515 -0.475157  0.350220  0.067677 -1.052250 -0.898375  0.663749
#
# [5 rows x 72 columns]

# %% [markdown]
# ## Создание модели

# %%
dims = base.shape[1]
n_cells = 25
quantizer = faiss.IndexFlatL2(dims)
idx_l2 = faiss.IndexIVFFlat(quantizer, dims, n_cells)

# %%
idx_l2.train(np.ascontiguousarray(base.values[:500000, :]).astype('float32'))

idx_l2.add(np.ascontiguousarray(base.values).astype('float32'))

# %%
base_index = {k: i for k, i in enumerate(base.index.tolist())}
list(base_index.items())[:3]
# Out:
# [(0, '0-base'), (1, '1-base'), (2, '2-base')]

# %%
vecs, idx = idx_l2.search(np.ascontiguousarray(features.values).astype('float32'), 100)

# %%
acc = 0
for trgt, el in zip(target.values.tolist(), idx.tolist()):
    acc += int(trgt in [base_index[i] for i in el])

print('Точность модели:', '{:.2%}'.format(acc / target.shape[0]))
# Out:
# Точность модели: 54.14%

# %%
df_cat = []
for i in range(idx.shape[0]): # Проходимся по всем ответам
    if i % 5000 == 0:
        print('{:.2%}'.format(i / idx.shape[0]))
    str_idx = [base_index[i] for i in idx[i]] # Создаём список индексов каждого ответа
    if target[i] in str_idx:
        df_cat.append(np.concatenate((features.iloc[i].values, base.loc[base.index == str_idx[str_idx.index(target[i])]].values[0], np.array([1]))))
        if target[i] == str_idx[0]:
            df_cat.append(np.concatenate((features.iloc[i].values, base.loc[base.index == str_idx[1]].values[0], np.array([0]))))
        else:
            df_cat.append(np.concatenate((features.iloc[i].values, base.loc[base.index == str_idx[0]].values[0], np.array([0]))))
# Out:
# 0.00%
# 5.00%
# 10.00%
# 15.00%
# 20.00%
# 25.00%
# 30.00%
# 35.00%
# 40.00%
# 45.00%
# 50.00%
# 55.00%
# 60.00%
# 65.00%
# 70.00%
# 75.00%
# 80.00%
# 85.00%
# 90.00%
# 95.00%

# %%
df_cat = pd.DataFrame(data=df_cat)
df_cat
# Out:
#              0         1         2         3         4         5         6    \
# 0       1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 1       1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 2       0.220765  1.367848 -0.389568 -0.045702 -1.145549  1.982654  0.427564
# 3       0.220765  1.367848 -0.389568 -0.045702 -1.145549  1.982654  0.427564
# 4      -0.291257 -0.946164 -0.462619 -1.250656  0.692396  0.504676  1.952317
# ...          ...       ...       ...       ...       ...       ...       ...
# 108283 -0.561866  0.072637 -0.774536 -1.890278 -0.939264 -0.340158 -1.143342
# 108284  1.216121 -0.592752  0.367880 -0.052078  3.193245 -0.973471  0.046847
# 108285  1.216121 -0.592752  0.367880 -0.052078  3.193245 -0.973471  0.046847
# 108286 -0.144157  0.660713 -0.243901  0.094449  0.664031 -0.470265  1.292502
# 108287 -0.144157  0.660713 -0.243901  0.094449  0.664031 -0.470265  1.292502
#
#              7         8         9    ...       135       136       137  \
# 0       0.258787 -2.153763 -1.474397  ...  1.712308  0.010568  0.428418
# 1       0.258787 -2.153763 -1.474397  ...  1.698041 -0.311033 -0.402364
# 2       0.375133  0.442602 -0.350126  ...  0.320632 -1.069614 -1.328515
# 3       0.375133  0.442602 -0.350126  ...  0.524454 -1.047661 -1.707922
# 4       0.827659 -0.728839 -0.679979  ... -0.950038  0.347621  0.729522
# ...          ...       ...       ...  ...       ...       ...       ...
# 108283 -1.056054 -0.934419  1.957286  ...  0.317893 -1.174631 -0.909449
# 108284  0.709647 -0.767644  1.021824  ... -1.971809 -0.745338  1.137116
# 108285  0.709647 -0.767644  1.021824  ... -2.083689 -0.918866 -1.244925
# 108286  0.848588 -0.788420 -0.813754  ... -1.250578  0.425201 -0.937286
# 108287  0.848588 -0.788420 -0.813754  ... -1.078429  0.616830 -0.897443
#
#              138       139       140       141       142       143  144
# 0      -0.496977  0.403141 -0.535591  0.083045  0.724239  0.735407  1.0
# 1      -1.143644  0.421038 -0.345688  0.731960  0.296695  0.291394  0.0
# 2      -0.474964  0.350176  0.067644 -1.052127 -0.898375  0.664229  1.0
# 3      -0.643422  0.366380  0.069110 -1.166881 -0.898375  0.787702  0.0
# 4      -1.698053  0.748115 -0.140631  0.543268 -0.223341  0.444216  1.0
# ...          ...       ...       ...       ...       ...       ...  ...
# 108283  1.919309 -0.693679  0.761175 -0.042787 -0.898375 -0.373225  0.0
# 108284 -0.140495  1.460118 -0.552218 -0.105679 -0.012652  1.226066  1.0
# 108285 -0.712622  1.648413 -0.687554 -0.155792 -0.012652  1.036396  0.0
# 108286 -0.497796  0.407031  0.909611 -0.673563  1.641060 -0.767811  1.0
# 108287  0.079053  0.943835  0.885049  1.064460  1.775719 -0.739909  0.0
#
# [108288 rows x 145 columns]

# %%
df_cat[144]
# Out:
# 0         1.0
# 1         0.0
# 2         1.0
# 3         0.0
# 4         1.0
#          ...
# 108283    0.0
# 108284    1.0
# 108285    0.0
# 108286    1.0
# 108287    0.0
# Name: 144, Length: 108288, dtype: float64

# %%
cat_features = df_cat.drop(144, axis=1)
cat_target = df_cat[144]

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

model = CatBoostClassifier(logging_level='Silent', loss_function='Logloss')
parameters_cbc = {'max_depth': np.arange(6, 11),
                  'learning_rate':[0.001, 0.01, 0.1, 1],
                  'iterations': [1000,1500,2000]}
catboost_grid = GridSearchCV(model,
                             parameters_cbc,
                             cv=3,
                             scoring='accuracy',
                             verbose=2).fit(cat_features, cat_target)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=6; total time=  32.1s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=6; total time=  32.0s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=6; total time=  31.9s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=7; total time=  45.0s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=7; total time=  45.5s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=7; total time=  46.2s
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=8; total time= 1.2min
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=8; total time= 1.2min
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=8; total time= 1.2min
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=9; total time= 2.0min
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=9; total time= 1.9min
# [CV] END ..iterations=1000, learning_rate=0.001, max_depth=9; total time= 2.0min
# [CV] END .iterations=1000, learning_rate=0.001, max_depth=10; total time= 5.4min
# [CV] END .iterations=1000, learning_rate=0.001, max_depth=10; total time= 5.4min
# [CV] END .iterations=1000, learning_rate=0.001, max_depth=10; total time= 5.5min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=6; total time=  34.3s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=6; total time=  34.0s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=6; total time=  34.0s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=7; total time=  47.1s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=7; total time=  45.4s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=7; total time=  45.0s
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=8; total time= 1.1min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=8; total time= 1.2min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=8; total time= 1.2min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=9; total time= 1.9min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=9; total time= 2.0min
# [CV] END ...iterations=1000, learning_rate=0.01, max_depth=9; total time= 1.9min
# [CV] END ..iterations=1000, learning_rate=0.01, max_depth=10; total time= 5.4min
# [CV] END ..iterations=1000, learning_rate=0.01, max_depth=10; total time= 5.5min
# [CV] END ..iterations=1000, learning_rate=0.01, max_depth=10; total time= 5.5min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=6; total time=  34.5s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=6; total time=  34.3s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=6; total time=  34.1s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=7; total time=  45.8s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=7; total time=  44.9s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=7; total time=  44.3s
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=8; total time= 1.1min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=8; total time= 1.1min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=8; total time= 1.1min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=9; total time= 1.9min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=9; total time= 1.9min
# [CV] END ....iterations=1000, learning_rate=0.1, max_depth=9; total time= 1.9min
# [CV] END ...iterations=1000, learning_rate=0.1, max_depth=10; total time= 5.3min
# [CV] END ...iterations=1000, learning_rate=0.1, max_depth=10; total time= 5.3min
# [CV] END ...iterations=1000, learning_rate=0.1, max_depth=10; total time= 5.4min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=6; total time=  33.6s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=6; total time=  33.3s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=6; total time=  33.2s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=7; total time=  44.1s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=7; total time=  42.8s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=7; total time=  42.3s
# [CV] END ......iterations=1000, learning_rate=1, max_depth=8; total time= 1.1min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=8; total time= 1.1min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=8; total time= 1.1min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=9; total time= 1.8min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=9; total time= 1.8min
# [CV] END ......iterations=1000, learning_rate=1, max_depth=9; total time= 1.8min
# [CV] END .....iterations=1000, learning_rate=1, max_depth=10; total time= 5.0min
# [CV] END .....iterations=1000, learning_rate=1, max_depth=10; total time= 5.1min
# [CV] END .....iterations=1000, learning_rate=1, max_depth=10; total time= 5.1min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=6; total time=  52.5s
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=6; total time=  51.1s
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=6; total time=  50.4s
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=7; total time= 1.1min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=7; total time= 1.1min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=7; total time= 1.1min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=8; total time= 1.7min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=8; total time= 1.7min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=8; total time= 1.7min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=9; total time= 2.9min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=9; total time= 2.9min
# [CV] END ..iterations=1500, learning_rate=0.001, max_depth=9; total time= 2.9min
# [CV] END .iterations=1500, learning_rate=0.001, max_depth=10; total time= 8.2min
# [CV] END .iterations=1500, learning_rate=0.001, max_depth=10; total time= 8.2min
# [CV] END .iterations=1500, learning_rate=0.001, max_depth=10; total time= 8.2min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=6; total time=  51.9s
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=6; total time=  50.7s
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=6; total time=  50.2s
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=7; total time= 1.1min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=7; total time= 1.2min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=7; total time= 1.1min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=8; total time= 1.7min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=8; total time= 1.7min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=8; total time= 1.7min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=9; total time= 2.9min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=9; total time= 2.9min
# [CV] END ...iterations=1500, learning_rate=0.01, max_depth=9; total time= 2.9min
# [CV] END ..iterations=1500, learning_rate=0.01, max_depth=10; total time= 8.1min
# [CV] END ..iterations=1500, learning_rate=0.01, max_depth=10; total time= 8.2min
# [CV] END ..iterations=1500, learning_rate=0.01, max_depth=10; total time= 8.1min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=6; total time=  51.8s
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=6; total time=  51.0s
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=6; total time=  49.8s
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=7; total time= 1.1min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=7; total time= 1.1min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=7; total time= 1.1min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=8; total time= 1.7min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=8; total time= 1.7min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=8; total time= 1.7min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=9; total time= 2.8min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=9; total time= 2.8min
# [CV] END ....iterations=1500, learning_rate=0.1, max_depth=9; total time= 2.8min
# [CV] END ...iterations=1500, learning_rate=0.1, max_depth=10; total time= 8.0min
# [CV] END ...iterations=1500, learning_rate=0.1, max_depth=10; total time= 8.1min
# [CV] END ...iterations=1500, learning_rate=0.1, max_depth=10; total time= 8.0min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=6; total time=  49.1s
# [CV] END ......iterations=1500, learning_rate=1, max_depth=6; total time=  48.4s
# [CV] END ......iterations=1500, learning_rate=1, max_depth=6; total time=  48.1s
# [CV] END ......iterations=1500, learning_rate=1, max_depth=7; total time= 1.1min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=7; total time= 1.0min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=7; total time= 1.0min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=8; total time= 1.6min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=8; total time= 1.6min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=8; total time= 1.6min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=9; total time= 2.6min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=9; total time= 2.6min
# [CV] END ......iterations=1500, learning_rate=1, max_depth=9; total time= 2.6min
# [CV] END .....iterations=1500, learning_rate=1, max_depth=10; total time= 7.5min
# [CV] END .....iterations=1500, learning_rate=1, max_depth=10; total time= 7.6min
# [CV] END .....iterations=1500, learning_rate=1, max_depth=10; total time= 7.6min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=6; total time= 1.2min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=6; total time= 1.1min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=6; total time= 1.1min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=7; total time= 1.5min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=7; total time= 1.5min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=7; total time= 1.5min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=8; total time= 2.3min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=8; total time= 2.3min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=8; total time= 2.3min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=9; total time= 3.9min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=9; total time= 3.9min
# [CV] END ..iterations=2000, learning_rate=0.001, max_depth=9; total time= 3.9min
# [CV] END .iterations=2000, learning_rate=0.001, max_depth=10; total time=10.9min
# [CV] END .iterations=2000, learning_rate=0.001, max_depth=10; total time=10.9min
# [CV] END .iterations=2000, learning_rate=0.001, max_depth=10; total time=10.9min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=6; total time= 1.2min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=6; total time= 1.1min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=6; total time= 1.1min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=7; total time= 1.5min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=7; total time= 1.5min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=7; total time= 1.5min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=8; total time= 2.3min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=8; total time= 2.3min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=8; total time= 2.3min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=9; total time= 3.8min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=9; total time= 3.9min
# [CV] END ...iterations=2000, learning_rate=0.01, max_depth=9; total time= 3.8min
# [CV] END ..iterations=2000, learning_rate=0.01, max_depth=10; total time=10.7min
# [CV] END ..iterations=2000, learning_rate=0.01, max_depth=10; total time=10.8min
# [CV] END ..iterations=2000, learning_rate=0.01, max_depth=10; total time=10.9min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=6; total time= 1.1min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=6; total time= 1.1min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=6; total time= 1.1min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=7; total time= 1.5min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=7; total time= 1.5min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=7; total time= 1.5min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=8; total time= 2.2min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=8; total time= 2.2min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=8; total time= 2.2min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=9; total time= 3.8min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=9; total time= 3.8min
# [CV] END ....iterations=2000, learning_rate=0.1, max_depth=9; total time= 3.8min
# [CV] END ...iterations=2000, learning_rate=0.1, max_depth=10; total time=10.6min
# [CV] END ...iterations=2000, learning_rate=0.1, max_depth=10; total time=10.7min
# [CV] END ...iterations=2000, learning_rate=0.1, max_depth=10; total time=10.7min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=6; total time= 1.1min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=6; total time= 1.0min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=6; total time= 1.0min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=7; total time= 1.4min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=7; total time= 1.4min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=7; total time= 1.4min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=8; total time= 2.1min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=8; total time= 2.1min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=8; total time= 2.1min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=9; total time= 3.5min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=9; total time= 3.5min
# [CV] END ......iterations=2000, learning_rate=1, max_depth=9; total time= 3.5min
# [CV] END .....iterations=2000, learning_rate=1, max_depth=10; total time=10.0min
# [CV] END .....iterations=2000, learning_rate=1, max_depth=10; total time=10.1min
# [CV] END .....iterations=2000, learning_rate=1, max_depth=10; total time=10.1min

# %%
catboost_grid.best_score_
# Out:
# 0.9125664893617021

# %%
model_cat = CatBoostClassifier(iterations = 2000,
                               learning_rate = 0.1,
                               max_depth = 9,
                               logging_level ='Silent',
                               loss_function ='Logloss').fit(cat_features, cat_target)

# %%
quantizer_ip = faiss.IndexFlatIP(dims)
idx_ip = faiss.IndexIVFFlat(quantizer_ip, dims, n_cells)

idx_ip.train(np.ascontiguousarray(base.values[:500000, :]).astype('float32'))

idx_ip.add(np.ascontiguousarray(base.values).astype('float32'))

# %%
vecs_ip, idx_ip = idx_ip.search(np.ascontiguousarray(features.values).astype('float32'), 100)

# %%
acc_ip = 0
for trgt_ip, el_ip in zip(target.values.tolist(), idx_ip.tolist()):
    acc_ip += int(trgt_ip in [base_index[i] for i in el_ip])

print('Точность модели:', '{:.2%}'.format(acc_ip / target.shape[0]))
# Out:
# Точность модели: 61.98%

# %%
idx_ip[0]
# Out:
# array([ 755584,  598613,  336969, 1934845,   13374, 1136231,  480296,
#         988777, 2360257,  583287,  450667, 1653095, 1818641, 1631947,
#         503716,  629775,   89840,  986050, 2346335, 1747988,  143978,
#         352715,  223859,  455829, 2295048, 1674977,  443428, 1375244,
#         854264,  751217, 1746258,  728097, 1113711,  199196, 2212973,
#         792610,  684958, 1546520, 1679537,  108138,  725525, 1299775,
#         458465,  164935,  669932, 2398299, 1307670, 2331892,   57113,
#        1285249,  679629, 2356601, 1037661,  547719,  232405, 1003399,
#         277931,  703484, 1472986, 1374819, 1228782, 2674563,   49353,
#         642286, 2700063,  851029,  113294, 1541141,  960901,  105660,
#         803577, 1012249,  454434, 2654893, 2711635,  233844,  264577,
#        1379669, 2860069, 2042379,   58509, 1379579, 1886302, 1407122,
#        1364891,  682218,  363988, 2815333, 2356997, 1131378, 2052752,
#         914354,  390350, 1713683, 2909593, 1091351, 2202395, 1628501,
#        1598432, 2882082], dtype=int64)

# %%
second_mode = []
str_idx_sec = [base_index[i] for i in idx_ip[0]]
for i in range(len(str_idx_sec)):
    second_mode.append(np.concatenate((features.iloc[0].values, base.loc[base.index == str_idx_sec[i]].values[0])))

# %%
second_mode = pd.DataFrame(data=second_mode)
second_mode
# Out:
#          0         1         2         3         4         5         6    \
# 0   1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 1   1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 2   1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 3   1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 4   1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 96  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 97  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 98  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
# 99  1.218659  2.079877  0.039629 -1.850675  1.587961 -0.486308  0.334226
#
#          7         8         9    ...       134       135       136       137  \
# 0   0.258787 -2.153763 -1.474397  ... -0.602001  1.698041 -0.311033 -0.402364
# 1   0.258787 -2.153763 -1.474397  ... -0.851277  1.712308  0.010568  0.428418
# 2   0.258787 -2.153763 -1.474397  ... -0.260577  1.821196 -0.434070  0.988730
# 3   0.258787 -2.153763 -1.474397  ... -0.441395  2.220264 -0.425010 -0.333752
# 4   0.258787 -2.153763 -1.474397  ... -0.209855  1.823598 -0.648673 -0.970468
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95  0.258787 -2.153763 -1.474397  ...  0.490877  2.263516 -0.383584 -1.493979
# 96  0.258787 -2.153763 -1.474397  ...  0.271724  1.569022 -0.715068 -0.112024
# 97  0.258787 -2.153763 -1.474397  ... -1.000115  1.358776 -0.504707  0.632585
# 98  0.258787 -2.153763 -1.474397  ... -0.542110  1.468388 -1.149459 -0.548859
# 99  0.258787 -2.153763 -1.474397  ... -0.224851  1.950718 -0.584061 -0.949320
#
#          138       139       140       141       142       143
# 0  -1.143644  0.421038 -0.345688  0.731960  0.296695  0.291394
# 1  -0.496977  0.403141 -0.535591  0.083045  0.724239  0.735407
# 2  -1.095766  0.289562 -0.460381  0.539531  0.295408  0.108781
# 3  -1.191454  0.165092 -1.226741  0.024671  1.644646  0.862929
# 4  -0.608199  0.329959 -0.644047  0.179109  1.945150  0.528980
# ..       ...       ...       ...       ...       ...       ...
# 95 -0.658389 -0.928480 -0.118126  0.158648 -0.898375  0.133643
# 96 -0.516561 -0.567459 -0.357619  0.011569 -0.319248  0.582949
# 97 -1.219792  0.121131 -0.221742 -0.138919 -0.898375  0.314993
# 98 -0.940821  0.273576 -0.487927  0.749021 -0.898375 -0.532712
# 99 -0.352867  0.502842  0.110447  0.155793 -0.898375 -0.104454
#
# [100 rows x 144 columns]

# %%
def predict_5(idx_ip, iteration):
    second_mode = []
    str_idx_sec = [base_index[i] for i in idx_ip[iteration]]
    for i in range(len(str_idx_sec)):
        second_mode.append(np.concatenate((test_features.iloc[iteration].values, base.loc[base.index == str_idx_sec[i]].values[0])))
    
    proba = model_cat.predict_proba(second_mode)

    proba = proba.tolist()
    for i in range(len(str_idx_sec)):
        proba[i].append(str_idx_sec[i])

    sorted_proba = sorted(proba, key=lambda x: x[1], reverse=True)

    true_idx = []
    for line in sorted_proba[:5]:
        true_idx.append(line[2])
    return true_idx

# %%
test = validation.join(validation_answer)
test_features = test.drop('Expected', axis=1)
test_target = test['Expected']

# %%
test_features_idx = test_features.index.tolist()
test_features_sc = scaler.transform(test_features)
test_features = pd.DataFrame(index=test_features_idx, data=test_features_sc)
test_features
# Out:
#                     0         1         2         3         4         5   \
# 100000-query  1.083408 -0.820601  0.778643  0.988113 -0.021481 -0.282074
# 100001-query  1.223466  1.034371  0.010189  0.572604  0.056169 -0.603834
# 100002-query  0.819788 -2.349909  0.920148 -1.176541 -0.321262  0.376098
# 100003-query -0.540937  1.707068  1.368014 -0.095025 -0.588534 -2.108414
# 100004-query  0.224609 -1.620082  0.706699 -1.211971  1.125420  1.562992
# ...                ...       ...       ...       ...       ...       ...
# 199995-query  1.498075 -0.205857  1.305098  1.467708 -0.665375  0.868079
# 199996-query -0.366522  0.643370  1.466786  1.003157 -1.891473 -0.572684
# 199997-query  1.011646  1.194903  1.695747  0.547724  0.700935  0.344747
# 199998-query  2.014247  0.808568  0.309102  0.911422 -0.758683  1.276888
# 199999-query  1.727314 -0.167816  0.349611 -0.498689 -0.061295  0.481853
#
#                     6         7         8         9   ...        62        63  \
# 100000-query -0.073071  1.797141 -1.569137 -0.784202  ...  0.183615  0.628320
# 100001-query -1.143342  0.648080  0.623842 -1.124457  ...  0.055540 -0.304162
# 100002-query -1.143342  1.003957  1.263425  0.659352  ... -1.748936  0.018554
# 100003-query  1.789113 -0.610416 -1.236203 -0.784341  ...  0.127444  0.284028
# 100004-query  1.700787  0.199737  0.898960 -0.370242  ... -1.389526  0.344580
# ...                ...       ...       ...       ...  ...       ...       ...
# 199995-query  1.515748  1.317251 -0.052086 -0.346256  ...  0.505431  1.022404
# 199996-query  1.865467 -1.026671  0.078687 -0.802422  ...  0.525258  0.044228
# 199997-query  1.185630 -0.075080  0.782827  0.658044  ...  1.053567  0.109693
# 199998-query -1.143342 -1.537520  0.099201 -1.435434  ...  0.477036 -0.832314
# 199999-query -0.582468 -0.965613 -0.550980 -1.109901  ... -0.010358 -0.334650
#
#                     64        65        66        67        68        69  \
# 100000-query  0.214130  0.454690  0.806680  0.701242  0.613806 -0.002273
# 100001-query -0.399385 -0.977745  1.613730 -1.604551  0.380450  0.380033
# 100002-query -0.181356 -1.344728 -0.048488  1.135248  1.032499  1.199692
# 100003-query  0.480081 -1.214390  1.678126  0.009890  0.960919  1.300299
# 100004-query  0.437936 -0.002688  1.533224 -0.138761  1.304700 -0.625011
# ...                ...       ...       ...       ...       ...       ...
# 199995-query  0.081796 -0.811519 -0.438645  0.964385 -0.110709 -0.135112
# 199996-query  0.940895 -0.327397 -1.978959 -2.524976  0.331406 -1.339543
# 199997-query  0.070371  1.479709  2.045514  0.039805 -1.758723 -0.799964
# 199998-query  0.223021  1.253450  0.231925  1.667144 -1.784805  1.594785
# 199999-query -0.475819  0.834716 -0.547475 -0.413552  1.648583  0.732922
#
#                     70        71
# 100000-query -0.959134 -1.663807
# 100001-query -0.085429  0.570094
# 100002-query  1.024018 -0.545043
# 100003-query -0.220717 -0.992043
# 100004-query -1.138368 -1.863456
# ...                ...       ...
# 199995-query  1.311427 -0.832199
# 199996-query -1.383739 -0.363592
# 199997-query  1.928378  0.495561
# 199998-query  1.322033 -0.301284
# 199999-query  0.224669  0.370930
#
# [100000 rows x 72 columns]

# %%
_, index = idx_l2.search(np.ascontiguousarray(test_features.values).astype('float32'), 100)

# %%
acc5 = 0
n = test_features.shape[0]
for i in range(n):
    ans = predict_5(index, i)
    acc5 += int(test_target[i] in ans)
print(acc5/n*100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[251], line 4
#       2 n = test_features.shape[0]
#       3 for i in range(n):
# ----> 4     ans = predict_5(index, i)
#       5     acc5 += int(test_target[i] in ans)
#       6 print(acc5/n*100)
#
# Cell In[224], line 5, in predict_5(idx_ip, iteration)
#       3 str_idx_sec = [base_index[i] for i in idx_ip[iteration]]
#       4 for i in range(len(str_idx_sec)):
# ----> 5     second_mode.append(np.concatenate((test_features.iloc[iteration].values, base.loc[base.index == str_idx_sec[i]].values[0])))
#       7 proba = model_cat.predict_proba(second_mode)
#       9 proba = proba.tolist()
#
# File C:\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\anaconda3\lib\site-packages\pandas\core\indexing.py:1292, in _LocIndexer._getitem_axis(self, key, axis)
#    1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
# -> 1292     return self._getbool_axis(key, axis=axis)
#    1293 elif is_list_like_indexer(key):
#    1294
#    1295     # an iterable multi-selection
#    1296     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File C:\anaconda3\lib\site-packages\pandas\core\indexing.py:1092, in _LocationIndexer._getbool_axis(self, key, axis)
#    1090 labels = self.obj._get_axis(axis)
#    1091 key = check_bool_indexer(labels, key)
# -> 1092 inds = key.nonzero()[0]
#    1093 return self.obj._take_with_is_copy(inds, axis=axis)
#
# KeyboardInterrupt:

# %%
acc5/i
# Out:
# 0.5820934144132488
